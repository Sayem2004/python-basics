# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayem2004/python-basics/blob/main/M_0C_basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programming basics in python

# %% [markdown]
# ### Numbers (int & float)

# %%
x = 3
print(type(x)) # Prints "<class 'int'>"
print(x)       # Prints "3"
print(x + 1)   # Addition; prints "4"
print(x - 1)   # Subtraction; prints "2"
print(x * 2)   # Multiplication; prints "6"
print(x ** 2)  # Exponentiation; prints "9"

x += 1
print(x)  # Prints "4"
x *= 2
print(x)  # Prints "8"
y = 2.5
print(type(y)) # Prints "<class 'float'>"
print(y, y + 1, y * 2, y ** 2) # Prints "2.5 3.5 5.0 6.25"
# Out:
# <class 'int'>
# 3
# 4
# 2
# 6
# 9
# 4
# 8
# <class 'float'>
# 2.5 3.5 5.0 6.25

# %%
# Practices
y = 4
print(type(y))
print(y)
print(y+1)
print(y-1)
print(y*3)
print(y**3)
print(y**2)
y -= 3
print(y)

y *= 5
print(y)
y += 6
print(y)

y = 2.5
print(type(y))
print(y, y + 1, y * 2, y ** 2)
# Out:
# <class 'int'>
# 4
# 5
# 3
# 12
# 64
# 16
# 1
# 5
# 11
# <class 'float'>
# 2.5 3.5 5.0 6.25

# %% [markdown]
# ### Booleans

# %%
t = True
f = False
print(type(t)) # Prints "<class 'bool'>"
print(t and f) # Logical AND; prints "False"
print(t or f)  # Logical OR; prints "True"
print(not t)   # Logical NOT; prints "False"
print(t != f)  # Logical XOR; prints "True"
# Out:
# <class 'bool'>
# False
# True
# False
# True

# %%
#Practices
t = True
f = False
print(type(t))
print(t and f)
# Out:
# <class 'bool'>
# False

# %% [markdown]
# ### String

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("""Print
Multiple
Lines
""")
# Out:
# Print
# Multiple
# Lines

# %%
#Practices
print("Good Morning \nhow are you ")
print("""
Good Night
Boys
""")
print("I can\'t believe it!")
print("I can't believe it!")
# Out:
# Good Morning
# how are you
#
# Good Night
# Boys
#
# I can't believe it!
# I can't believe it!

# %%
a = 10
print(f'The value of a is {a}')
# Out:
# The value of a is 10

# %%
#Practices
a = 5
print("value is {a}")
# Out:
# value is 5

# %%
a = 10
print(f'The value of a plus 5 is {a+5}')
# Out:
# The value of a plus 5 is 15

# %%
a = 5

print(f'a is {a}') # Preferred method for this course.
print('a is {}'.format(a))
print('a is ' + str(a))
print('a is %d %d' % (a, a))
# Out:
# a is 5
# a is 5
# a is 5
# a is 5 5

# %%
#practices
x = 5
print('a is {}'.format(x))
print('a is ' + str(x))
print('a is %d %d' % (x,x))
# Out:
# a is 5
# a is 5
# a is 5 5

# %% [markdown]
# **Condition checking**

# %%
a = 5
b = 6

if a==5:
    print('The variable a is 5')
    if b==6:
        print('The variable b is also 6')
elif a==6:
    print('The variable a is 6')
else:
    print('anything')
# Out:
# The variable a is 5
# The variable b is also 6

# %% [markdown]
# ### Looping

# %%
for x in range(1, 9):  # If you ever see xrange, you are in Python 2
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(10,1,-1):
    # range(start (optional, default 0), end (exclusive), inc/dec (optional, default 1))
    print('test: ', i)
# Out:
# test:  10
# test:  9
# test:  8
# test:  7
# test:  6
# test:  5
# test:  4
# test:  3
# test:  2

# %%
acc = 0
for x in range(1, 10):
    print(f"{acc} + {x} =  ", end="")
    acc += x
    print(acc)

print(f"Final sum: {acc}")
# Out:
# 0 + 1 =  1
# 1 + 2 =  3
# 3 + 3 =  6
# 6 + 4 =  10
# 10 + 5 =  15
# 15 + 6 =  21
# 21 + 7 =  28
# 28 + 8 =  36
# 36 + 9 =  45
# Final sum: 45
