# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayem2004/python-basics/blob/main/Firstt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Sayem")

print(3)
#print("Al-Imran")

"""
This is a comment
written in
more than just one line
"""
# Out:
# Sayem
# 3
# '\nThis is a comment\nwritten in\nmore than just one line\n'

# %%
print("This a \t python program.\n WE are doing it in google colab.")
# Out:
# This a 	 python program.
#  WE are doing it in google colab.

# %%
print("Hello World  ")
# Out:
# Hello World

# %% [markdown]
# List

# %%
li =["a",2,'d',2,2,5,True,False]
print(li)
print(type(li))
li[1] = 10
print(li)
# Out:
# ['a', 2, 'd', 2, 2, 5, True, False]
# <class 'list'>
# ['a', 10, 'd', 2, 2, 5, True, False]
